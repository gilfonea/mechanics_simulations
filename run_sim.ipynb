# %%
import asyncio
from models.two_bodies_on_incline import Two_bodies_on_incline

sim = Two_bodies_on_incline()

# הפעלת האנימציה כמשימת רקע אסינכרונית, מה שמאפשר לתא "לסיים" לרוץ
asyncio.create_task(sim.start_web())
